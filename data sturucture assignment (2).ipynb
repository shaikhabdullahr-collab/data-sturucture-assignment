# %% [markdown]
#                                                         Theoratical Questions

# %% [markdown]
# #Q1 What are data structures, and why are they important?
# -> Data structures are systematic ways of organizing, storing, and managing data in a computer so it can be accessed and modified efficiently.
#    Importance of D.S
#    Efficiency,Better performance at scale,Problem-solving,Cleaner and more maintainable code,Foundation of algorithms,
#    Data structures are important because they determine how efficiently a program stores, accesses, and processes data.

# %% [markdown]
# #Q2 Explain the difference between mutable and immutable data types with examples?
# -> Mutable data types
#    Mutable objects can be modified in place—their memory reference stays the same, but their contents change.
#    # List (mutable)
# numbers = [1, 2, 3]
# numbers.append(4)
# print(numbers)   # [1, 2, 3, 4]

# %% [markdown]
# #Q3  What are the main differences between lists and tuples in Python?
# ->List → Mutable (can be changed after creation)
# Tuple → Immutable (cannot be changed after creation)

# %% [markdown]
# #Q4 Describe how dictionaries store data?
# -> A dictionary in Python stores data as key–value pairs. Each key is used to uniquely identify and access its corresponding value.

# %% [markdown]
# #Q5 Why might you use a set instead of a list in Python?
# ->The main difference is
# A set automatically removes duplicates.
#
# A list allows duplicate values.

# %% [markdown]
# #Q6 What is a string in Python, and how is it different from a list?
# -> A string in Python is a sequence of characters used to represent text.
#
# String → Contains only characters,Immutable (cannot be changed),Strings cannot be modified in place.
#
# List → Can contain different data types,Mutable (can be changed),Lists can be modified using methods like append(), remove(), insert().,

# %% [markdown]
# #Q7  How do tuples ensure data integrity in Python?
# ->  Tuples help ensure data integrity in Python because they are immutable, meaning their contents cannot be changed once created. This makes them reliable for storing data that should remain constant.

# %% [markdown]
# #Q8 What is a hash table, and how does it relate to dictionaries in Python?
# -> A hash table is a data structure that stores data in an array-like structure using a key and a hash function.
# The hash function converts a key into an index (hash value), which tells the program where to store or find the data.

# %% [markdown]
# #Q9 Can lists contain different data types in Python?
# ->  list can store elements of any data type together

# %% [markdown]
# #Q10 Explain why strings are immutable in Python?
# -> In Python, strings are immutable, which means once a string is created, it cannot be changed.
#
#   Python can reuse the same string object in memory when the value is the same.
#   If strings were mutable, changing one would affect all references to it.
#
#   Immutable objects are faster to access and manage.
#    Operations like string concatenation create a new string instead of modifying the original.

# %% [markdown]
# #Q11 What advantages do dictionaries offer over lists for certain tasks?
# -> Dictionaries use keys instead of indexes.
#    Accessing a value by key is much faster than searching a list.
#
#    Data is stored as key–value pairs, making it easier to understand.
#    Lists rely on position, which can be confusing.
#
#    Finding a value in a list may require checking each element.
#    Dictionaries find values directly using keys.
#
#    Dictionaries ensure unique keys, preventing ambiguity.
#     Lists can contain duplicate values.

# %% [markdown]
# #Q12 Describe a scenario where using a tuple would be preferable over a list?
# -> A tuple is preferable over a list when you need to store fixed, unchangeable data and want to ensure data integrity and efficiency.
#
# working with geographical coordinates or graph points.
#
# Why a tuple is better here:
#
# Coordinates should not change accidentally
#
#  Immutable, so values stay constant
#
#  Faster than lists
#
#  Can be used as a dictionary key

# %% [markdown]
# #Q13 How do sets handle duplicate values in Python?
# -> In Python, a set automatically removes duplicate values.
# A set stores only unique elements, so if you try to add the same value more than once, it will appear only one time.

# %% [markdown]
# #Q14 How does the “in” keyword work differently for lists and dictionaries?
# ->* in with Lists
# Checks whether a value (element) exists in the list.
# Python searches sequentially through the list.
#
# *in with Dictionaries
# Checks whether a key exists in the dictionary (not the value).
# Uses hashing, so the lookup is very fast.

# %% [markdown]
# #Q15  Can you modify the elements of a tuple? Explain why or why not?
# -> Tuples are immutable, which means once a tuple is created, its elements cannot be changed, added, or removed.

# %% [markdown]
# #Q16 What is a nested dictionary, and give an example of its use case?
# -> it’s a dictionary inside a dictionary, used to represent structured or hierarchical data.
# A nested dictionary is useful when:
#
# You need to store multiple records
#
# Each record has multiple attributes
#
# Eg School / college databases,Employee records,Product catalogs

# %% [markdown]
# #Q17 Describe the time complexity of accessing elements in a dictionary?
# ->Accessing an element in a dictionary in Python is very fast because dictionaries are implemented using hash tables.
# When you access a value using a key, Python:
# Computes the hash of the key
# Directly finds the memory location
# This makes lookup time constant, regardless of dictionary size.

# %% [markdown]
# #Q18 In what situations are lists preferred over dictionaries?
# -> Lists are preferred over dictionaries when you need an ordered collection of items that can be accessed by index and when key–value mapping is not required.

# %% [markdown]
# #Q19  Why are dictionaries considered unordered, and how does that affect data retrieval?
# -> Dictionaries are considered unordered because they store data using hashing, not by position, so values are retrieved by keys rather than by order.

# %% [markdown]
# #Q20  Explain the difference between a list and a dictionary in terms of data retrieval?
# -> Lists retrieve data using numeric indexes (positions), while dictionaries retrieve data using unique keys, making dictionary lookups faster and more meaningful.

# %% [markdown]
#                                                 #PRACTICAL QUESTIONS

# %%
#Q1 Write a code to create a string with your name and print it?
name = "Abdulla Shaikh"
print(name)
# Out:
# Abdulla Shaikh

# %%
#Q2 Write a code to find the length of the string "Hello World"?
a= "Hello World"
len(a)
# Out:
# 11

# %%
#Q3 Write a code to slice the first 3 characters from the string "Python Programming"?
a="Python Programming"
a[0:3]
# Out:
# 'Pyt'

# %%
#Q4 Write a code to convert the string "hello" to uppercase?
a="hello"
a.upper()
# Out:
# 'HELLO'

# %%
#Q5 Write a code to replace the word "apple" with "orange" in the string "I like apple"?
S="I like apple"
S_new=S.replace("apple","orange")
S_new
# Out:
# 'I like orange'

# %%
#Q6 Write a code to create a list with numbers 1 to 5 and print it?
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Q7  Write a code to append the number 10 to the list [1, 2, 3, 4]?
a=[1,2,3,4]
a.append(10)
a
# Out:
# [1, 2, 3, 4, 10]

# %%
#Q8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]?
a=[1,2,3,4,5]
a.remove(3)
a
# Out:
# [1, 2, 4, 5]

# %%
#Q9  Write a code to access the second element in the list ['a', 'b', 'c', 'd']?
my_list= ['a', 'b', 'c', 'd']
my_list[1]
# Out:
# 'b'

# %%
#Q10  Write a code to reverse the list [10, 20, 30, 40, 50]?
abd=[10,20,30,40,50]
abd[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
#Q11 Write a code to create a tuple with the elements 100, 200, 300 and print it?
my_tuple = (100, 200, 300)
print(my_tuple)
# Out:
# (100, 200, 300)

# %%
#Q12 Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')?
t=('red', 'green', 'blue', 'yellow')
t[1:]
# Out:
# ('green', 'blue', 'yellow')

# %%
#Q13 Write a code to find the minimum number in the tuple (10, 20, 5, 15)?
t=(10, 20, 5, 15)
min(t)
# Out:
# 5

# %%
#Q14 Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')?
t=('dog', 'cat', 'rabbit')
t.index('cat')
# Out:
# 1

# %%
#Q15 Write a code to create a tuple containing three different fruits and check if "kiwi" is in it?
t=("mango","Banana","kiwi")
print("kiwi"in t)
# Out:
# True

# %%
#Q16 Write a code to create a set with the elements 'a', 'b', 'c' and print it?
Alphabets={'a', 'b', 'c'}
print(Alphabets)
# Out:
# {'b', 'a', 'c'}

# %%
#Q17 Write a code to clear all elements from the set {1, 2, 3, 4, 5}?
abd={1,2,3,4,5}
abd.clear()
abd
# Out:
# set()

# %%
#Q18  Write a code to remove the element 4 from the set {1, 2, 3, 4}?
Numbers={1,2,3,4}
Numbers.remove(4)
Numbers
# Out:
# {1, 2, 3}

# %%
#Q19 Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}?
A={1,2,3}
B={3,4,5}
A|B
# Out:
# {1, 2, 3, 4, 5}

# %%
#Q20 Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}?
A={1,2,3}
b={2,3,4}
A&B
# Out:
# {3}

# %%
#Q21 Write a code to create a dictionary with the keys "name", "age", and "city", and print it?
Client={"name":"Abdulla","age":29,"City":"Solapur"}
print(Client)
# Out:
# {'name': 'Abdulla', 'age': 29, 'City': 'Solapur'}

# %%
#Q22 Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}?
employ1={'name': 'John', 'age': 25}
employ1["country"]="USA"
employ1
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#Q23  Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}?
employ2={'name': 'Alice', 'age': 30}
employ2['name']
# Out:
# 'Alice'

# %%
#Q24 Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}?
employ3={'name': 'Bob', 'age': 22, 'city': 'New York'}
del employ3 ['age']
employ3
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#Q25 Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}?
worker={'name': 'Alice', 'city': 'Paris'}
worker.get("city")
# Out:
# 'Paris'

# %%
#Q26 Write a code to create a list, a tuple, and a dictionary, and print them all?
my_list = [1, 2, 3]
my_tuple = (4, 5, 6)
my_dict = {"a": 10, "b": 20}

print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3]
# (4, 5, 6)
# {'a': 10, 'b': 20}

# %%
#Q27  Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)?
import random

numbers = random.sample(range(1, 101), 5)
numbers.sort()
print(numbers)
# Out:
# [6, 54, 72, 75, 78]

# %%
#Q28 Write a code to create a list with strings and print the element at the third index?
strings = ["apple", "banana", "cherry", "date"]
print(strings[3])
# Out:
# date

# %%
#Q29 Write a code to combine two dictionaries into one and print the result.
a={"Johnson":"nauman"}
b={"Mufti":"Nauman"}
a|b
# Out:
# {'Johnson': 'nauman', 'Mufti': 'Nauman'}

# %%
#Q30  Write a code to convert a list of strings into a set.
w= ["apple", "banana", "apple", "orange"]
t= set(w)
print(t)
# Out:
# {'orange', 'banana', 'apple'}
